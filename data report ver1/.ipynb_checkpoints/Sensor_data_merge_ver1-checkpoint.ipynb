# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sensor_data_jung = pd.read_csv("data/data_namuk/sensor_jung_all.csv")
sensor_data_jung = sensor_data_jung.rename(columns = {'Unnamed: 0': 'index'})
sensor_data_jung = sensor_data_jung.set_index('index')

# %%
sensor_data_jung.describe()
# Out:
#                 LAX           LAY           LAZ        LA_mad        LA_max  \
# count  11690.000000  11690.000000  11690.000000  11690.000000  11690.000000
# mean     124.015056    135.680411    118.244311     51.158331    191.989393
# std       73.603794     72.072049     78.469864     22.354579     47.939091
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       64.000000     76.000000     44.000000     33.777778    160.000000
# 50%      120.000000    144.000000    112.000000     51.555556    204.000000
# 75%      188.000000    196.000000    192.000000     68.444444    232.000000
# max      252.000000    252.000000    252.000000    111.111111    252.000000
#
#             LA_mean     LA_median        LA_min   LA_quantile       LA_skew  \
# count  11690.000000  11690.000000  11690.000000  11690.000000  11690.000000
# mean     125.979926    126.541660     59.408725    126.541660     -0.001170
# ...

# %%
sensor_data_gun = pd.read_csv("data/data_namuk/sensor_gun_all.csv")
sensor_data_gun = sensor_data_gun.rename(columns = {'Unnamed: 0': 'index'})
sensor_data_gun = sensor_data_gun.set_index('index')

# %%
sensor_data_gun.describe()
# Out:
#                LAX          LAY         LAZ       LA_mad       LA_max  \
# count  6725.000000  6725.000000  6725.00000  6725.000000  6725.000000
# mean    122.336952   126.388699   126.45948    50.247402   190.039554
# std      74.104313    73.741735    74.09264    22.455100    49.992899
# min       0.000000     0.000000     0.00000     0.000000     8.000000
# 25%      56.000000    64.000000    64.00000    32.888889   160.000000
# 50%     120.000000   124.000000   128.00000    50.666667   204.000000
# 75%     184.000000   192.000000   192.00000    67.555556   232.000000
# max     252.000000   252.000000   252.00000   109.333333   252.000000
#
#            LA_mean    LA_median       LA_min  LA_quantile      LA_skew  \
# count  6725.000000  6725.000000  6725.000000  6725.000000  6725.000000
# mean    125.061710   124.667955    60.477621   124.667955     0.018539
# std      42.177040    56.459816    48.461570    56.459816     1.254799
# ...

# %%
sensor_data_all = pd.concat([sensor_data_gun, sensor_data_jung], ignore_index=True)
sensor_data_all.describe()
# Out:
#                 LAX           LAY           LAZ        LA_mad        LA_max  \
# count  18415.000000  18415.000000  18415.000000  18415.000000  18415.000000
# mean     123.402226    132.287157    121.244420     50.825667    191.277328
# std       73.789386     72.821813     76.999869     22.395027     48.706861
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       60.000000     72.000000     52.000000     33.777778    160.000000
# 50%      120.000000    140.000000    120.000000     51.555556    204.000000
# 75%      188.000000    196.000000    192.000000     68.444444    232.000000
# max      252.000000    252.000000    252.000000    111.111111    252.000000
#
#             LA_mean     LA_median        LA_min   LA_quantile       LA_skew  \
# count  18415.000000  18415.000000  18415.000000  18415.000000  18415.000000
# mean     125.644601    125.857399     59.799077    125.857399      0.006028
# ...

# %%
print(sensor_data_all['label'].value_counts())
# Out:
# 5     8587
# 20    3508
# 10    3218
# 15    3102
# Name: label, dtype: int64

# %%
sensor_data_all.to_csv("data/data_namuk/sensor_data_all.csv", mode='w')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e5ae2f9ff7f5> in <module>()
# ----> 1 sensor_data_all.to_csv("data/data_namuk/sensor_data_all.csv", mode='w')
#
# NameError: name 'sensor_data_all' is not defined
